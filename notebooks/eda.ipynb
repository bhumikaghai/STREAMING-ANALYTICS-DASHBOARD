# %%
import pandas as pd

# %%
df=pd.read_csv("../datasets/netflix_titles.csv")
df.head()
# Out:
#     show_id                                title                    director  \
# 0  81193313                            Chocolate                         NaN
# 1  81197050  Guatemala: Heart of the Mayan World  Luis Ara, Ignacio Jaunsolo
# 2  81213894                      The Zoya Factor             Abhishek Sharma
# 3  81082007                            Atlantics                   Mati Diop
# 4  80213643                      Chip and Potato                         NaN
#
#                                                 cast  \
# 0  Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...
# 1                                  Christian Morales
# 2  Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3  Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 4  Abigail Oliver, Andrea Libman, Briana Buckmast...
#
#                     country         date_added  release_year rating  \
# 0               South Korea  November 30, 2019          2019  TV-14
# ...

# %%
df.shape
# Out:
# (5837, 12)

# %%
df.columns
# Out:
# Index(['show_id', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'type'],
#       dtype='str')

# %%
df.info
# Out:
# <bound method DataFrame.info of        show_id                                title  \
# 0     81193313                            Chocolate
# 1     81197050  Guatemala: Heart of the Mayan World
# 2     81213894                      The Zoya Factor
# 3     81082007                            Atlantics
# 4     80213643                      Chip and Potato
# ...        ...                                  ...
# 5832  70141644          Mad Ron's Prevues from Hell
# 5833  70127998                             Splatter
# 5834  70084180              Just Another Love Story
# 5835  70157452                      Dinner for Five
# 5836  70053412                 To and From New York
#
#                         director  \
# 0                            NaN
# 1     Luis Ara, Ignacio Jaunsolo
# 2                Abhishek Sharma
# 3                      Mati Diop
# 4                            NaN
# ...                          ...
# 5832                  Jim Monaco
# ...

# %%
df.type
# Out:
# 0       TV Show
# 1         Movie
# 2         Movie
# 3         Movie
# 4       TV Show
#          ...
# 5832      Movie
# 5833      Movie
# 5834      Movie
# 5835    TV Show
# 5836      Movie
# Name: type, Length: 5837, dtype: str

# %%
df.isnull().sum()
# Out:
# show_id            0
# title              0
# director        1901
# cast             556
# country          427
# date_added       642
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# type               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["type"].unique()
# Out:
# <StringArray>
# ['TV Show', 'Movie']
# Length: 2, dtype: str

# %%
df["type"].value_counts()
# Out:
# type
# Movie      3939
# TV Show    1898
# Name: count, dtype: int64

# %%
df["listed_in"].head()
# Out:
# 0    International TV Shows, Korean TV Shows, Roman...
# 1                  Documentaries, International Movies
# 2               Comedies, Dramas, International Movies
# 3     Dramas, Independent Movies, International Movies
# 4                                             Kids' TV
# Name: listed_in, dtype: str

# %%
df["listed_in"].unique()
# Out:
# <StringArray>
# [       'International TV Shows, Korean TV Shows, Romantic TV Shows',
#                                'Documentaries, International Movies',
#                             'Comedies, Dramas, International Movies',
#                   'Dramas, Independent Movies, International Movies',
#                                                           'Kids' TV',
#                          'Comedies, International Movies, Thrillers',
#                                       'Dramas, International Movies',
#  'Crime TV Shows, International TV Shows, Spanish-Language TV Shows',
#                                     'Comedies, International Movies',
#                 'Comedies, Independent Movies, International Movies',
#  ...
#                     'Crime TV Shows, TV Dramas, TV Sci-Fi & Fantasy',
#              'Documentaries, Faith & Spirituality, Music & Musicals',
#                    'Children & Family Movies, Comedies, Cult Movies',
# ...

# %%
df["listed_in"].nunique()
# Out:
# 449

# %%
df["listed_in"].value_counts()
# Out:
# listed_in
# Documentaries                                             297
# Stand-Up Comedy                                           265
# Dramas, International Movies                              238
# Dramas, Independent Movies, International Movies          170
# Comedies, Dramas, International Movies                    157
#                                                          ...
# British TV Shows, International TV Shows, TV Horror         1
# Classic & Cult TV, Kids' TV, TV Comedies                    1
# Children & Family Movies, Documentaries, Sports Movies      1
# Docuseries, Stand-Up Comedy & Talk Shows                    1
# Children & Family Movies, Classic Movies, Comedies          1
# Name: count, Length: 449, dtype: int64

# %%
df["listed_in"].str.split()
# Out:
# 0       [International, TV, Shows,, Korean, TV, Shows,...
# 1                 [Documentaries,, International, Movies]
# 2             [Comedies,, Dramas,, International, Movies]
# 3       [Dramas,, Independent, Movies,, International,...
# 4                                             [Kids', TV]
#                               ...
# 5832                      [Cult, Movies,, Horror, Movies]
# 5833                                     [Horror, Movies]
# 5834                     [Dramas,, International, Movies]
# 5835                   [Stand-Up, Comedy, &, Talk, Shows]
# 5836           [Dramas,, Independent, Movies,, Thrillers]
# Name: listed_in, Length: 5837, dtype: object

# %%
df["listed_in"].str.strip()
# Out:
# 0       International TV Shows, Korean TV Shows, Roman...
# 1                     Documentaries, International Movies
# 2                  Comedies, Dramas, International Movies
# 3        Dramas, Independent Movies, International Movies
# 4                                                Kids' TV
#                               ...
# 5832                           Cult Movies, Horror Movies
# 5833                                        Horror Movies
# 5834                         Dramas, International Movies
# 5835                         Stand-Up Comedy & Talk Shows
# 5836                Dramas, Independent Movies, Thrillers
# Name: listed_in, Length: 5837, dtype: str

# %%
df["release_year"].min()
# Out:
# np.int64(1925)

# %%
df["release_year"].max()
# Out:
# np.int64(2020)

# %%
df["release_year"].value_counts()
# Out:
# release_year
# 2018    1040
# 2017     928
# 2016     818
# 2019     762
# 2015     502
#         ...
# 1966       1
# 1963       1
# 1969       1
# 1947       1
# 1954       1
# Name: count, Length: 71, dtype: int64

# %%
df.groupby("release_year").size()
# Out:
# release_year
# 1925       1
# 1942       2
# 1943       3
# 1944       3
# 1945       3
#         ...
# 2016     818
# 2017     928
# 2018    1040
# 2019     762
# 2020       1
# Length: 71, dtype: int64

# %%
df.sort_values("release_year")
# Out:
#        show_id                                          title  \
# 2154  81030762              Pioneers: First Women Filmmakers*
# 4929  60027945                                 Prelude to War
# 4931  60027942                           The Battle of Midway
# 4943  70013050             Why We Fight: The Battle of Russia
# 4941  80119186  Undercover: How to Operate Behind Enemy Lines
# ...        ...                                            ...
# 1276  80236341                                          Maria
# 8     70205672                               La Reina del Sur
# 26    81177504   The Body Remembers When the World Broke Open
# 27    80175798                                   The Irishman
# 133   81034946                             Maradona in Mexico
#
#                                        director  \
# 2154                                        NaN
# 4929                                Frank Capra
# 4931                                  John Ford
# ...

# %%
df["country"].unique()
# Out:
# <StringArray>
# [                                                         'South Korea',
#                                                                     nan,
#                                                                 'India',
#                                              'France, Senegal, Belgium',
#                                                'Canada, United Kingdom',
#                                                               'Nigeria',
#                                                                'France',
#                                                          'South Africa',
#                                'United States, Spain, Colombia, Mexico',
#                                                         'United States',
#  ...
#                                'United Kingdom, Ukraine, United States',
#                               'Norway, United Kingdom, France, Ireland',
#                 'United Kingdom, United States, Greece, Italy, Germany',
# ...

# %%
df["country"].value_counts()
# Out:
# country
# United States                              1907
# India                                       697
# United Kingdom                              336
# Japan                                       168
# Canada                                      139
#                                            ...
# United Kingdom,                               1
# United States, Bermuda, Ecuador               1
# United States, Hungary, Ireland, Canada       1
# United Kingdom, Egypt, United States          1
# Spain, Mexico, France                         1
# Name: count, Length: 527, dtype: int64

# %%
df["country"].replace
# Out:
# <bound method NDFrame.replace of 0                    South Korea
# 1                            NaN
# 2                          India
# 3       France, Senegal, Belgium
# 4         Canada, United Kingdom
#                   ...
# 5832               United States
# 5833               United States
# 5834                     Denmark
# 5835               United States
# 5836               United States
# Name: country, Length: 5837, dtype: str>

# %%
df["country"].str.strip()
# Out:
# 0                    South Korea
# 1                            NaN
# 2                          India
# 3       France, Senegal, Belgium
# 4         Canada, United Kingdom
#                   ...
# 5832               United States
# 5833               United States
# 5834                     Denmark
# 5835               United States
# 5836               United States
# Name: country, Length: 5837, dtype: str

# %%
df["duration"].unique()
# Out:
# <StringArray>
# [ '1 Season',    '67 min',   '135 min',   '106 min', '2 Seasons',   '107 min',
#     '81 min',   '118 min',   '110 min',   '104 min',
#  ...
#    '187 min',   '193 min',   '192 min',   '224 min',   '172 min',    '18 min',
#    '179 min',    '37 min',   '180 min',    '43 min']
# Length: 194, dtype: str

# %%
df["duration"].str.extract
# Out:
# <bound method StringMethods.extract of <pandas.core.strings.accessor.StringMethods object at 0x0000022D0F7A4130>>

# %%
df["duration"].str.split()
# Out:
# 0        [1, Season]
# 1          [67, min]
# 2         [135, min]
# 3         [106, min]
# 4       [2, Seasons]
#             ...
# 5832       [84, min]
# 5833       [29, min]
# 5834      [104, min]
# 5835     [1, Season]
# 5836       [81, min]
# Name: duration, Length: 5837, dtype: object

# %%
df["duration"].value_counts()
# Out:
# duration
# 1 Season     1259
# 2 Seasons     298
# 3 Seasons     157
# 90 min        105
# 91 min        101
#              ...
# 18 min          1
# 179 min         1
# 37 min          1
# 180 min         1
# 43 min          1
# Name: count, Length: 194, dtype: int64

# %%
df["listed_in"].value_counts()
# Out:
# listed_in
# Documentaries                                             297
# Stand-Up Comedy                                           265
# Dramas, International Movies                              238
# Dramas, Independent Movies, International Movies          170
# Comedies, Dramas, International Movies                    157
#                                                          ...
# British TV Shows, International TV Shows, TV Horror         1
# Classic & Cult TV, Kids' TV, TV Comedies                    1
# Children & Family Movies, Documentaries, Sports Movies      1
# Docuseries, Stand-Up Comedy & Talk Shows                    1
# Children & Family Movies, Classic Movies, Comedies          1
# Name: count, Length: 449, dtype: int64

# %%
df.groupby("country").sum()
# Out:
#                                                        show_id  \
# country
# Argentina                                           3016917525
# Argentina, Brazil, France, Poland, Germany, Den...    80202808
# Argentina, Chile                                      80236993
# Argentina, Chile, Peru                                80106928
# Argentina, France                                     80232892
# ...                                                        ...
# Uruguay, Spain, Mexico                                81025973
# Venezuela                                             80193423
# Venezuela, Colombia                                   70204282
# Vietnam                                              323284488
# West Germany                                          80106791
#
#                                                                                                 title  \
# country
# ...

# %% [markdown]
# # Data Visualization

# %%
import seaborn as sns

# %% [markdown]
# ## Distribution of Movies and TV Shows

# %%
sns.countplot(x="type", data = df)
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %% [markdown]
# Movies are significantly more common than TV Shows in the dataset.

# %% [markdown]
# ## ## Content Distribution by Country

# %%
sns.countplot(x="country" , data=df)
# Out:
# <Axes: xlabel='country', ylabel='count'>

# %% [markdown]
# The United States contributes the highest number of titles in the dataset.

# %% [markdown]
# ## Number of Titles Released Each Year

# %%
sns.countplot(x="release_year" , data=df)
# Out:
# <Axes: xlabel='release_year', ylabel='count'>

# %% [markdown]
# The number of released titles increased rapidly in recent years.

# %% [markdown]
# ## Distribution of Content Ratings

# %%
sns.countplot(x="rating", data=df)
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %% [markdown]
# TV-MA and TV-14 are among the most common ratings, indicating that a large portion of the content is targeted toward mature audiences.

# %% [markdown]
# ## Number of Titles Released Each Year

# %%
sns.countplot(x="release_year",data=df)
# Out:
# <Axes: xlabel='release_year', ylabel='count'>

# %% [markdown]
# The number of released titles increased rapidly in recent years.

# %% [markdown]
# ## Content Distribution by Country

# %%
sns.countplot(x="country" ,data=df)
# Out:
# <Axes: xlabel='country', ylabel='count'>

# %% [markdown]
# The United States contributes the highest number of titles in the dataset, followed by other major content-producing countries.

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Trend of Content Releases Over the Years

# %%
sns.lineplot(
    x=df["release_year"].value_counts().sort_index().index,
    y=df["release_year"].value_counts().sort_index().values
)

plt.show()

# %% [markdown]
# The number of released titles increased significantly after 2015.

# %% [markdown]
# ## the percentage share of Movies and TV Shows

# %%
df["type"].value_counts().plot.pie()
# Out:
# <Axes: >

# %% [markdown]
# Movies make up the majority of content in the dataset compared to TV Shows.

# %% [markdown]
# ##  Distribution of Content Ratings

# %%
df["rating"].value_counts().plot.pie()
# Out:
# <Axes: >

# %% [markdown]
# TV-MA and TV-14 are among the most common content ratings in the dataset.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Distribution of Release Years

# %%
plt.hist(df["release_year"])
plt.show()

# %% [markdown]
# Most content in the dataset was released after 2010.

# %% [markdown]
# ## Distribution of Content Duration

# %%
plt.hist(df["duration"])
plt.show()

# %% [markdown]
# Most movies have durations concentrated around standard feature-length timings.

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Missing Values Analysis

# %%
df.isnull().sum()
# Out:
# show_id            0
# title              0
# director        1901
# cast             556
# country          427
# date_added       642
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# type               0
# dtype: int64

# %% [markdown]
# Some columns contain missing values that may require cleaning before further analysis.

# %% [markdown]
# ## Duplicate Values Check

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No duplicate rows were found in the dataset.

# %%
## Handle Missing Values

# %%
df.dropna()
# Out:
#        show_id                                   title              director  \
# 2     81213894                         The Zoya Factor       Abhishek Sharma
# 3     81082007                               Atlantics             Mati Diop
# 5     81172754                            Crazy people          Moses Inwang
# 6     81120982                          I Lost My Body         Jérémy Clapin
# 7     81227195  Kalushi: The Story of Solomon Mahlangu           Mandla Dube
# ...        ...                                     ...                   ...
# 5831  70154110                           Even the Rain         Icíar Bollaín
# 5832  70141644             Mad Ron's Prevues from Hell            Jim Monaco
# 5833  70127998                                Splatter             Joe Dante
# 5834  70084180                 Just Another Love Story          Ole Bornedal
# 5836  70053412                    To and From New York  Sorin Dan Mihalcescu
#
# ...

# %% [markdown]
# Missing values were handled to improve data quality and analysis accuracy.

# %% [markdown]
# ## Remove Duplicates

# %%
df.drop_duplicates()
# Out:
#        show_id                                title  \
# 0     81193313                            Chocolate
# 1     81197050  Guatemala: Heart of the Mayan World
# 2     81213894                      The Zoya Factor
# 3     81082007                            Atlantics
# 4     80213643                      Chip and Potato
# ...        ...                                  ...
# 5832  70141644          Mad Ron's Prevues from Hell
# 5833  70127998                             Splatter
# 5834  70084180              Just Another Love Story
# 5835  70157452                      Dinner for Five
# 5836  70053412                 To and From New York
#
#                         director  \
# 0                            NaN
# 1     Luis Ara, Ignacio Jaunsolo
# 2                Abhishek Sharma
# 3                      Mati Diop
# 4                            NaN
# ...                          ...
# 5832                  Jim Monaco
# 5833                   Joe Dante
# ...

# %% [markdown]
# Duplicate records were removed to maintain dataset consistency.

# %% [markdown]
# ## Check Data Types

# %%
df.dtypes
# Out:
# show_id         int64
# title             str
# director          str
# cast              str
# country           str
# date_added        str
# release_year    int64
# rating            str
# duration          str
# listed_in         str
# description       str
# type              str
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5837 entries, 0 to 5836
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5837 non-null   int64
#  1   title         5837 non-null   str
#  2   director      3936 non-null   str
#  3   cast          5281 non-null   str
#  4   country       5410 non-null   str
#  5   date_added    5195 non-null   str
#  6   release_year  5837 non-null   int64
#  7   rating        5827 non-null   str
#  8   duration      5837 non-null   str
#  9   listed_in     5837 non-null   str
#  10  description   5837 non-null   str
#  11  type          5837 non-null   str
# dtypes: int64(2), str(10)
# memory usage: 547.3 KB

# %% [markdown]
# The dataset contains both numeric and categorical columns used for analysis and visualization.

# %% [markdown]
# ## Clean Duration Column

# %%
df.astype
# Out:
# <bound method NDFrame.astype of        show_id                                title  \
# 0     81193313                            Chocolate
# 1     81197050  Guatemala: Heart of the Mayan World
# 2     81213894                      The Zoya Factor
# 3     81082007                            Atlantics
# 4     80213643                      Chip and Potato
# ...        ...                                  ...
# 5832  70141644          Mad Ron's Prevues from Hell
# 5833  70127998                             Splatter
# 5834  70084180              Just Another Love Story
# 5835  70157452                      Dinner for Five
# 5836  70053412                 To and From New York
#
#                         director  \
# 0                            NaN
# 1     Luis Ara, Ignacio Jaunsolo
# 2                Abhishek Sharma
# 3                      Mati Diop
# 4                            NaN
# ...                          ...
# 5832                  Jim Monaco
# ...

# %% [markdown]
# The duration column was cleaned and converted into a more usable numeric format.

# %% [markdown]
# # Final Conclusion

# %% [markdown]
# This project analyzed Netflix movies and TV shows data using Pandas and visualization libraries. The analysis showed that Movies are more common than TV Shows, and content releases increased significantly after 2015. The United States contributed the highest number of titles, while TV-MA was one of the most common ratings. Overall, the project helped identify trends and patterns in streaming platform content.
